# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from pprint import pprint

# magic to import packages from parent directory
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

from src import utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x1, y1 = utils.convert_to_3day_mean_format(utils.load_artembev())

prokopbev, volkov = utils.load_others()

x2, y2 = utils.convert_to_3day_mean_format(prokopbev)
x3, y3 = utils.convert_to_3day_mean_format(volkov)

# %%
tree = DecisionTreeRegressor(max_depth=1)

# %%
utils.train_and_test(tree, x1, y1)
# Out:
# R² на отложенной выборке: 0.5327834090783292

# %%
utils.train_and_test_nosplit(tree, x1, y1)
# Out:
# R² на всей выборке: 0.48494123159339975

# %%
utils.train_and_test(tree, x2, y2)
# Out:
# R² на отложенной выборке: -0.1416748939957997

# %%
utils.train_and_test_nosplit(tree, x2, y2)
# Out:
# R² на всей выборке: 0.1406997597694174

# %%
tree = DecisionTreeRegressor(max_depth=2)

# %%
utils.train_and_test(tree, x3, y3)
# Out:
# R² на отложенной выборке: 0.3539631444225684

# %%
utils.train_and_test_nosplit(tree, x3, y3)
# Out:
# R² на всей выборке: 0.3833255655932254
