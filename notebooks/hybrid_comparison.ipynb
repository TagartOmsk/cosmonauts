# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from pprint import pprint

# magic to import packages from parent directory
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

from src.tree_boosting import TreeBoosting
from src import utils 

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Hybrid

# %%
tree = TreeBoosting(2)
x1, y1 = utils.convert_to_3day_mean_format(utils.load_artembev())

# %%
utils.train_and_test(tree, x1, y1, test_size=0.2)
# Out:
# R² на отложенной выборке: 0.09307601560296719

# %%
utils.train_and_test_nosplit(tree, x1, y1)
# Out:
# R² на всей выборке: 0.73420692109285

# %%
prokopbev, volkov = utils.load_others()

# %%
x2, y2 = utils.convert_to_3day_mean_format(prokopbev)
x3, y3 = utils.convert_to_3day_mean_format(volkov)

# %%
tree = TreeBoosting(1)
utils.train_and_test(tree, x2, y2, test_size=0.2)
# Out:
# R² на отложенной выборке: -0.9474022544166338

# %%
utils.train_and_test_nosplit(tree, x2, y2)
# Out:
# R² на всей выборке: 0.3050793438602635

# %%
tree = TreeBoosting(2)
utils.train_and_test(tree, x3, y3, test_size=0.2)
# Out:
# R² на отложенной выборке: 0.18612517814164342

# %%
utils.train_and_test_nosplit(tree, x3, y3)
# Out:
# R² на всей выборке: 0.48228666592234715
