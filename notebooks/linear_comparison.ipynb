# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from pprint import pprint

# magic to import packages from parent directory
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

from src import utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x1, y1 = utils.convert_to_3day_mean_format(utils.load_artembev())

prokopbev, volkov = utils.load_others()

x2, y2 = utils.convert_to_3day_mean_format(prokopbev)
x3, y3 = utils.convert_to_3day_mean_format(volkov)

# %%
model = LinearRegression(fit_intercept=True)

# %%
utils.train_and_test(model, x1, y1)
# Out:
# R² на отложенной выборке: 0.4635699775074965

# %%
utils.train_and_test_nosplit(model, x1, y1)
# Out:
# R² на всей выборке: 0.43314979962526834

# %%
utils.train_and_test(model, x2, y2)
# Out:
# R² на отложенной выборке: 0.12621896267581034

# %%
utils.train_and_test_nosplit(model, x2, y2)
# Out:
# R² на всей выборке: 0.15250963531658135

# %%
utils.train_and_test(model, x3, y3)
# Out:
# R² на отложенной выборке: 0.10560197302626861

# %%
utils.train_and_test_nosplit(model, x3, y3)
# Out:
# R² на всей выборке: 0.2765216064736745
